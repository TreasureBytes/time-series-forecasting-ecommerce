# %%
from src.params import *
from src.all_imports import *

from src.utils.data_utils import *
from src.steps.data_preparation import *
from src.steps.data_analysis import *

# %%
# download and extract data
download_data()
# Out:
# Dataset URL: https://www.kaggle.com/datasets/aslanahmedov/walmart-sales-forecast
# License(s): copyright-authors
# ...
# 100%|██████████| 3.36M/3.36M [00:01<00:00, 1.87MB/s]
# 2025-01-19 08:17:32 - INFO - Extracted walmart-sales-forecast.zip to: /Users/saikiran/Documents/workspace/git_workspace/time-series-forecasting-ecommerce/data/raw
# 2025-01-19 08:17:35 - INFO - Deleted: /Users/saikiran/Documents/workspace/git_workspace/time-series-forecasting-ecommerce/data/walmart-sales-forecast.zip

# %%
# load, prepare, preprocess data
processed_train, processed_test = data_processing()
# Out:
# 2025-01-19 08:17:35 - INFO - Data Pipeline
# 2025-01-19 08:17:35 - INFO - Loading data from: /Users/saikiran/Documents/workspace/git_workspace/time-series-forecasting-ecommerce/data/raw
# 2025-01-19 08:17:35 - INFO - Loading '/Users/saikiran/Documents/workspace/git_workspace/time-series-forecasting-ecommerce/data/raw/test.csv'...
# 2025-01-19 08:17:35 - INFO - Loading '/Users/saikiran/Documents/workspace/git_workspace/time-series-forecasting-ecommerce/data/raw/train.csv'...
# 2025-01-19 08:17:35 - INFO - Loading '/Users/saikiran/Documents/workspace/git_workspace/time-series-forecasting-ecommerce/data/raw/features.csv'...
# 2025-01-19 08:17:35 - INFO - Loading '/Users/saikiran/Documents/workspace/git_workspace/time-series-forecasting-ecommerce/data/raw/stores.csv'...
# 2025-01-19 08:17:35 - INFO - All data files are loaded!
# 2025-01-19 08:17:35 - INFO - Data preparation started:
# ...

# %%
# eda, feature engineering
train = exploratory_data_analysis(processed_train)
test = exploratory_data_analysis(processed_test)
# Out:
# 2025-01-19 08:17:38 - INFO - Exploratory Data Analysis: TRAIN
# 2025-01-19 08:17:38 - INFO - Summary Statistics:
# 2025-01-19 08:17:38 - INFO - Distribution Plot:
# Summary Stats:
# ╒═══════╤═════════════╤═════════════╤═══════════════════════════════╤════════════════╤═══════════════╤═══════════════╤═════════════╤═════════════╤═════════════╤═════════════╤═════════════╤═════════════╤════════════════╤══════════╕
# │       │       store │        dept │ date                          │   weekly_sales │   temperature │    fuel_price │   markdown1 │   markdown2 │   markdown3 │   markdown4 │   markdown5 │         cpi │   unemployment │     size │
# ╞═══════╪═════════════╪═════════════╪═══════════════════════════════╪════════════════╪═══════════════╪═══════════════╪═════════════╪═════════════╪═════════════╪═════════════╪═════════════╪═════════════╪════════════════╪══════════╡
# ...

# %%
train.head()
# Out:
#    store  dept       date  weekly_sales  isholiday  temperature  fuel_price  \
# 0      1     1 2010-02-05      24924.50          0        42.31       2.572
# 1      1     1 2010-02-12      46039.49          1        38.51       2.548
# 2      1     1 2010-02-19      41595.55          0        39.93       2.514
# 3      1     1 2010-02-26      19403.54          0        46.63       2.561
# 4      1     1 2010-03-05      21827.90          0        46.50       2.625
#
#      markdown1    markdown2    markdown3  ...  sales_roll_1  sales_roll_2  \
# 0  6915.330281  3155.401504  1644.807471  ...           NaN           NaN
# 1  5173.960000  1053.980000   188.330000  ...      24924.50           NaN
# 2  6915.330281  3155.401504  1644.807471  ...      46039.49     35481.995
# 3  6915.330281  3155.401504  1644.807471  ...      41595.55     43817.520
# 4  6915.330281  3155.401504  1644.807471  ...      19403.54     30499.545
#
# ...

# %%
# processed_train.groupby('date')['weekly_sales'].sum().reset_index().to_clipboard(index=False)
